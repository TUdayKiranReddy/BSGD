# %%
import soundfile as sf

# %%
path = '/home/solomon/dataset/SSP/Voice.flac'

time = 2

data, samplerate = sf.read(path, start=0, stop=int(44100*time))

# %%
import IPython

IPython.display.Audio(data[:, 0], rate=samplerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa

# %%
y, sr = librosa.load(path, sr=16000, mono=True, duration=time)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(y)

# %%
import numpy as np

# %%
Ry = np.corrcoef(y, y)

# %%
plt.imshow(Ry)

# %%
Ry
# Out:
# array([[1., 1.],
#        [1., 1.]])
